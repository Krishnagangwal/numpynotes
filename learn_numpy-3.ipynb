# %% [markdown]
# ## Advance Operation with Business examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data structure: [restaurant_id, 2021, 2022, 2023, 2024]
sales_data = np.array([
    [1, 150000, 180000, 220000, 250000], # La classic biryani
    [2, 120000, 140000, 160000, 190000], # belgian fries
    [3, 200000, 230000, 260000, 300000], #pizza ceconi
    [4, 180000, 210000, 240000, 270000], # gupta bhelpuri
    [5, 160000, 185000, 205000, 230000], # tambi sandwich
])

print("===== Zomato Sales Analysis =====")
print("\n Sales Data Shape", sales_data.shape)
print("\n Sales of first 3 restaurants: \n", sales_data[:3])
# Out:
# ===== Zomato Sales Analysis =====
#
#  Sales Data Shape (5, 5)
#
#  Sales of first 3 restaurants:
#  [[     1 150000 180000 220000 250000]
#  [     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 300000]]

# %%
# total sales per year 
print(np.sum(sales_data, axis=0))
yearly_total = np.sum(sales_data[:, 1:], axis = 0)
print("yearly total sales : ", yearly_total)

#Minimum sales per restaurant
min_sales = np.min(sales_data[:, 1:], axis = 1)
print("minimum sales are: ", min_sales)

#Maximum sales per year
max_sales = np.max(sales_data[:, 1:], axis = 0)
print("Maximum sales are: ", max_sales)

#Average sales per restaurant
avg_sales = np.mean(sales_data[:, 1:], axis=1)
print("Average sales : ", avg_sales)
# Out:
# [     15  810000  945000 1085000 1240000]
# yearly total sales :  [ 810000  945000 1085000 1240000]
# minimum sales are:  [150000 120000 200000 180000 160000]
# Maximum sales are:  [200000 230000 260000 300000]
# Average sales :  [200000. 152500. 247500. 225000. 195000.]

# %%
cumsum = np.cumsum(sales_data[:, 1:], axis = 1)
print("Cumulative sum of sales :", cumsum )

plt.figure(figsize=(10,6))
plt.plot(np.mean(cumsum, axis = 0))
plt.title("Average cumulative Sales across all restaurants")
plt.xlabel("Years")
plt.ylabel("Sales")
plt.grid(True)
plt.show()
# Out:
# Cumulative sum of sales : [[150000 330000 550000 800000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 990000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]

# %%
vector1 = np.array([1,2,3,4,5])
vector2 = np.array([6,7,8,9,10])

print("Vector addition vector: ", vector1 + vector2)

print("\n Vector multiplication vector: ", vector1 * vector2)

print("\n Dot multiplication vector: ", np.dot(vector1, vector2))\

angle = np.arccos(np.dot(vector1, vector2) / (np.linalg.norm(vector1) * np.linalg.norm(vector2)))
print(angle)
# Out:
# Vector addition vector:  [ 7  9 11 13 15]
#
#  Vector multiplication vector:  [ 6 14 24 36 50]
#
#  Dot multiplication vector:  130
# 0.26554161733900966

# %%
restaurant_types = np.array (['biryani', 'chinese', 'pizza', 'burger', 'cafe'])
vectorized_upper = np.vectorize(str.upper)
print("Vectorized upper", vectorized_upper(restaurant_types))
# Out:
# Vectorized upper ['BIRYANI' 'CHINESE' 'PIZZA' 'BURGER' 'CAFE']

# %%
monthly_avg = sales_data[:, 1:] / 12

print(monthly_avg)
# Out:
# [[12500.         15000.         18333.33333333 20833.33333333]
#  [10000.         11666.66666667 13333.33333333 15833.33333333]
#  [16666.66666667 19166.66666667 21666.66666667 25000.        ]
#  [15000.         17500.         20000.         22500.        ]
#  [13333.33333333 15416.66666667 17083.33333333 19166.66666667]]
